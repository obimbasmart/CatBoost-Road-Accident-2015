# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

Accident=pd.read_csv('dataset/cleaned_data.csv')

# %%
Accident.head()
# Out:
#          Date  Longitude   Latitude         Police_Force Accident_Severity  \
# 0  2015-12-01  -0.198465  51.505538  Metropolitan Police            Slight
# 1  2015-12-01  -0.178838  51.491836  Metropolitan Police            Slight
# 2  2015-12-01  -0.205590  51.514910  Metropolitan Police            Slight
# 3  2015-01-13  -0.208327  51.514952  Metropolitan Police            Slight
# 4  2015-09-01  -0.206022  51.496572  Metropolitan Police           Serious
#
#    Number_of_Vehicles  Number_of_Casualties Day_of_Week                 Time  \
# 0                   1                     1      Monday  1900-01-01 18:45:00
# 1                   1                     1      Monday  1900-01-01 07:50:00
# 2                   1                     1      Monday  1900-01-01 18:08:00
# 3                   1                     1     Tuesday  1900-01-01 07:40:00
# 4                   2                     1      Friday  1900-01-01 07:30:00
#
# ...

# %%
Accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140056 entries, 0 to 140055
# Data columns (total 24 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   Date                                         140056 non-null  object
#  1   Longitude                                    140056 non-null  float64
#  2   Latitude                                     140056 non-null  float64
#  3   Police_Force                                 140056 non-null  object
#  4   Accident_Severity                            140056 non-null  object
#  5   Number_of_Vehicles                           140056 non-null  int64
#  6   Number_of_Casualties                         140056 non-null  int64
#  7   Day_of_Week                                  140056 non-null  object
#  8   Time                                         140056 non-null  object
# ...

# %%
sns.catplot(x='Urban_or_Rural_Area', data=Accident, kind='count')
plt.show()

# %%
sns.catplot(x='Did_Police_Officer_Attend_Scene_of_Accident', data=Accident, kind='count')
plt.show()

# %%
sns.catplot(x='Road_Surface_Conditions', data=Accident, kind='count')
plt.show()

# %%
sns.catplot(x='Weather_Conditions', data=Accident, kind='count')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Light_Conditions', data=Accident, kind='count')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Pedestrian_Crossing-Physical_Facilities', data=Accident, kind='count')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Road_Type', data=Accident, kind='count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # summary of Accidents causes
# Majority of the accideents occured on single carriageways, without any physical crossing facilities within 50 meters and in day light,
# when there were no high winds and the roads were dry. ***So most natural factors weren't the causes of majority of this accidents but instead we can say that the single carriage ways had a huge part to play***

# %%
sns.catplot(x='Accident_Severity', data=Accident, kind='count')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Day_of_Week',y='Number_of_Vehicles', data=Accident, kind='point')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Day_of_Week',y='Number_of_Casualties', data=Accident, kind='point')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Day_of_Week',y='Number_of_Casualties', data=Accident, kind='box')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x='Day_of_Week',y='Number_of_Vehicles', data=Accident, kind='box')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # day of the week
# Though we see an average of fewer vehicles involved in accidents during the weekend, we see a greater average for the number of casualties during the weekend also. Therefore the accidents that occurerd during the weekend most especially sunday and Saturday though few here a lot more fatal

# %%
sns.relplot(x='Date',y='Number_of_Casualties', data=Accident, kind='scatter')
plt.show()

# %%
sns.relplot(x='Date',y='Number_of_Vehicles', data=Accident, kind='scatter')
plt.show()

# %% [markdown]
# # changes with time
# There has thankfully not been any upward trends over time in the number of casualities or number of vehicles

# %%
sns.relplot(x='Time',y='Number_of_Vehicles', data=Accident, kind='scatter')
plt.show()

# %%
sns.stripplot(x='Day_of_Week',y='Number_of_Casualties',data=Accident)
plt.xticks(rotation=90)
plt.show()

# %%
sns.stripplot(x='Day_of_Week',y='Number_of_Vehicles',data=Accident)
plt.xticks(rotation=90)
plt.show()
