# %%
import numpy as np
import pandas as pd

# %%
road_df = pd.read_csv("UK_Traffic_Accidents_2015.csv")
road_df.head()
# Out:
# C:\Users\OMNL\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201501BS70001               525130.0                180050.0  -0.198465
# 1  201501BS70002               526530.0                178560.0  -0.178838
# 2  201501BS70004               524610.0                181080.0  -0.205590
# 3  201501BS70005               524420.0                181080.0  -0.208327
# 4  201501BS70008               524630.0                179040.0  -0.206022
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.505538             1                  3                   1
# 1  51.491836             1                  3                   1
# 2  51.514910             1                  3                   1
# ...

# %%
road_df.shape
# Out:
# (140056, 32)

# %%
road_df.isnull().sum()
# Out:
# Accident_Index                                    0
# Location_Easting_OSGR                            27
# Location_Northing_OSGR                           27
# Longitude                                        27
# Latitude                                         27
# Police_Force                                      0
# Accident_Severity                                 0
# Number_of_Vehicles                                0
# Number_of_Casualties                              0
# Date                                              0
# Day_of_Week                                       0
# Time                                             18
# Local_Authority_(District)                        0
# Local_Authority_(Highway)                         0
# 1st_Road_Class                                    0
# 1st_Road_Number                                   0
# Road_Type                                         0
# Speed_limit                                       0
# ...

# %%
road_df.count()
# Out:
# Accident_Index                                 140056
# Location_Easting_OSGR                          140029
# Location_Northing_OSGR                         140029
# Longitude                                      140029
# Latitude                                       140029
# Police_Force                                   140056
# Accident_Severity                              140056
# Number_of_Vehicles                             140056
# Number_of_Casualties                           140056
# Date                                           140056
# Day_of_Week                                    140056
# Time                                           140038
# Local_Authority_(District)                     140056
# Local_Authority_(Highway)                      140056
# 1st_Road_Class                                 140056
# 1st_Road_Number                                140056
# Road_Type                                      140056
# ...
